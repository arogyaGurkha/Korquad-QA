# %%
# !git clone https://github.com/monologg/KoELECTRA
# !pip install transformers==3.3.1 seqeval fastprogress attrdict
# Out:
# Cloning into 'KoELECTRA'...
# remote: Enumerating objects: 586, done.
# remote: Counting objects: 100% (303/303), done.
# remote: Compressing objects: 100% (134/134), done.
# remote: Total 586 (delta 223), reused 232 (delta 168), pack-reused 283
# Receiving objects: 100% (586/586), 55.30 MiB | 21.19 MiB/s, done.
# Resolving deltas: 100% (354/354), done.
# Checking out files: 100% (164/164), done.
# ...
#      |████████████████████████████████| 1.1MB 8.4MB/s
# ...
#      |████████████████████████████████| 51kB 8.8MB/s
# ...
#      |████████████████████████████████| 901kB 31.6MB/s
# ...
#      |████████████████████████████████| 3.0MB 50.1MB/s
# ...
#      |████████████████████████████████| 1.2MB 49.2MB/s
# ...
#   Created wheel for seqeval: filename=seqeval-1.2.2-cp37-none-any.whl size=16184 sha256=a618e4ad46de27dcb764e88ce27e56ab0c8e0b4b88e5c86e0f2429a506e5b76f
#   Stored in directory: /root/.cache/pip/wheels/52/df/1b/45d75646c37428f7e626214704a0e35bd3cfc32eda37e59e5f
# Successfully built seqeval
# ...

# %%
# %cd KoELECTRA/finetune/
# Out:
# /content/KoELECTRA/finetune

# %%
# !python run_squad.py --task korquad --config_file xlm-roberta.json
# Out:
# 2021-07-13 05:30:29.250071: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# 07/13/2021 05:30:31 - INFO - filelock -   Lock 140269531996240 acquired on /root/.cache/torch/transformers/762ddd751172e9d3229e5da17a459eee6c0dfdc237c718944d0b1a85f06c7e1e.2b0f807393c56e8861a31cd67d2fc0b45d71d9735dd47dd66afb650f90b6d2a8.lock
# Downloading: 100% 512/512 [00:00<00:00, 472kB/s]
# 07/13/2021 05:30:31 - INFO - filelock -   Lock 140269531996240 released on /root/.cache/torch/transformers/762ddd751172e9d3229e5da17a459eee6c0dfdc237c718944d0b1a85f06c7e1e.2b0f807393c56e8861a31cd67d2fc0b45d71d9735dd47dd66afb650f90b6d2a8.lock
# 07/13/2021 05:30:32 - INFO - filelock -   Lock 140269531996240 acquired on /root/.cache/torch/transformers/0c370616ddfc06067c0634160f749c2cf9d8da2c50e03a2617ce5841c8df3b1d.309f0c29486cffc28e1e40a2ab0ac8f500c203fe080b95f820aa9cb58e5b84ed.lock
# Downloading: 100% 5.07M/5.07M [00:00<00:00, 9.43MB/s]
# ...

# %%
# !python run_squad.py --task korquad --config_file koelectra-base.json
# Out:
# Streaming output truncated to the last 5000 lines.
# <IPython.core.display.HTML object>
# <IPython.core.display.HTML object>
# <IPython.core.display.HTML object>
# <IPython.core.display.HTML object>
# <IPython.core.display.HTML object>
# <IPython.core.display.HTML object>
# <IPython.core.display.HTML object>
# <IPython.core.display.HTML object>
# <IPython.core.display.HTML object>
# <IPython.core.display.HTML object>
# <IPython.core.display.HTML object>
# <IPython.core.display.HTML object>
# <IPython.core.display.HTML object>
# <IPython.core.display.HTML object>
# <IPython.core.display.HTML object>
# <IPython.core.display.HTML object>
# <IPython.core.display.HTML object>
# <IPython.core.display.HTML object>
# <IPython.core.display.HTML object>
# <IPython.core.display.HTML object>
# <IPython.core.display.HTML object>
# <IPython.core.display.HTML object>
# <IPython.core.display.HTML object>
# <IPython.core.display.HTML object>
# <IPython.core.display.HTML object>
# ...
